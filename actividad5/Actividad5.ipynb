# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl
from datetime import datetime

# %%
# Leer archivo de datos 00Z
# Convertir la columna CAPE de objeto a número
df0 = pd.read_csv("00Z.csv", header=None, names=['Date', 'CAPE', 'PW'])
df0.CAPE=pd.to_numeric(df0.CAPE, errors='coerce')
df0.head()
# Out:
#          Date  CAPE     PW
# 0  01 01 2017   0.0   6.88
# 1  02 01 2017   0.0   3.94
# 2  03 01 2017   0.0  10.01
# 3  04 01 2017   0.0   5.80
# 4  05 01 2017   0.0   9.44

# %%
df0.dtypes
# Out:
# Date     object
# CAPE    float64
# PW      float64
# dtype: object

# %%
# Convertir la cadena de caracteres 'Date' en variable temporal 'NDate'
df0['Ndate'] = pd.to_datetime(df0['Date'], format= '%d %m %Y')
df0['month'] = df0['Ndate'].dt.month
df0.head()
# Out:
#          Date  CAPE     PW      Ndate  month
# 0  01 01 2017   0.0   6.88 2017-01-01      1
# 1  02 01 2017   0.0   3.94 2017-01-02      1
# 2  03 01 2017   0.0  10.01 2017-01-03      1
# 3  04 01 2017   0.0   5.80 2017-01-04      1
# 4  05 01 2017   0.0   9.44 2017-01-05      1

# %%
# graficar Boxplots por mes 00Z
# Biblioteca Seaborn
import seaborn as seb
ax = seb.boxplot(x="month", y="CAPE", data=df0)
mpl.show()

# %%
# graficar Boxplots por mes 00Z
# Biblioteca Seaborn
ax = seb.boxplot(x="month", y="PW", data=df0)
mpl.show()

# %%
#Datos 00Z
seb.set(style="darkgrid", color_codes=True)

g = seb.jointplot("CAPE", "PW", data=df0, kind="reg",
                   color="y", size=7)
mpl.show(g)

# %%
#Datos 00Z
g = seb.lmplot(x="CAPE", y="PW", hue="month",
               truncate=True, size=5, data=df0)
mpl.show(g)

# %%
#realizar para 12Z
df1 = pd.read_csv("00Z.csv", header=None, names=['Date', 'CAPE', 'PW'])
df1.CAPE=pd.to_numeric(df1.CAPE, errors='coerce')
df1.head()
# Out:
#          Date  CAPE     PW
# 0  01 01 2017   0.0   6.88
# 1  02 01 2017   0.0   3.94
# 2  03 01 2017   0.0  10.01
# 3  04 01 2017   0.0   5.80
# 4  05 01 2017   0.0   9.44

# %%
# Convertir la cadena de caracteres 'Date' en variable temporal 'NDate'
df1['Ndate'] = pd.to_datetime(df1['Date'], format='%d %m %Y')
df1['month'] = df1['Ndate'].dt.month
df1.head()
# Out:
#          Date  CAPE     PW      Ndate  month
# 0  01 01 2017   0.0   6.88 2017-01-01      1
# 1  02 01 2017   0.0   3.94 2017-01-02      1
# 2  03 01 2017   0.0  10.01 2017-01-03      1
# 3  04 01 2017   0.0   5.80 2017-01-04      1
# 4  05 01 2017   0.0   9.44 2017-01-05      1

# %%
# graficar Boxplots por mes 12Z
ax = seb.boxplot(x="month", y="CAPE", data=df1)
mpl.show()

# %%
#boxplot por mes 12Z
ax = seb.boxplot(x="month", y="PW", data=df1)
mpl.show()

# %%
#12Z
seb.set(style="darkgrid", color_codes=True)

g = seb.jointplot("CAPE", "PW", data=df1, kind="reg",
                   color="b", size=7)
mpl.show(g)

# %%
#12Z
g = seb.lmplot(x="CAPE", y="PW", hue="month",
               truncate=True, size=5, data=df1)
mpl.show(g)
