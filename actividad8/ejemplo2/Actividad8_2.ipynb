# %%
import numpy as np
def vectorfield(w, t, p):
    """
    Defines the differential equations for the Van der Pol.

    Arguments:
        w :  vector of the state variables:
                  w = [x,y]
        t :  time
        p :  vector of the parameters:
                  
    """
    x, y = w

    # Create f = (x1',y1'):
    f = [y, (m*(1-x**2)*y)-(x)]
    return f

# %%
# Use ODEINT to solve the differential equations defined by the vector field
from scipy.integrate import odeint


#Coeficiente no lineal
#m = 0.0
# Initial conditions
# x1 and x2 are the initial displacements
x = -3
y = -3

# ODE solver parameters
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 300.0
numpoints = 5000

# Create the time samples for the output of the ODE solver.
# I use a large number of points, only because I want to make
# a plot of the solution that looks nice.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
w0 = [x, y]


numbers=[0.01,0.1,0.5,1.0,1.5,2.0,2.5,3.0,3.5,4.0]
for m in numbers:
# Call the ODE solver.
    wsol=odeint(vectorfield, w0, t, args=(m,),
              atol=abserr, rtol=relerr)
    
    with open('m'+str(m)+'.dat', 'w') as f:
    # Print & save the solution.
        for t1, w1 in zip(t, wsol):
            print  (t1, w1[0], w1[1], file=f)

# %%
import numpy as np
from matplotlib.font_manager import FontProperties
import math
import numpy as np
import matplotlib.pyplot as mpl
#Nueva Gráfica #Velocidad2 Vs Posición2
import math
import numpy as np
from pylab import savefig
import matplotlib.pyplot as mpl
##############################33
##############################

fig = mpl.figure(figsize=(4,8))

numbers=[0.01,0.1,0.5,1.0,1.5,2.0,2.5,3.0,3.5,4.0]
for m in numbers:
    t, x, y = np.loadtxt('m'+str(m)+'.dat', unpack=True, skiprows=2000)
    mpl.plot(x,y,label='m'+str(m)+'') 
    
mpl.legend(loc='best')    
mpl.title('Velocidad2-Posición2/Tiempo')
mpl.grid()
mpl.savefig('xD.png', dpi=100)
mpl.show()

# %%
#ssh -x edyndz7@148.225.73.30
#lp -d feynman f.pdf
