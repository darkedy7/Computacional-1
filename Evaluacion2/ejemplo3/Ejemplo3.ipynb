# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

rho = 46.92
sigma = 28.0
beta = 4.0

def f(state, t):
    x, y, z = state  # unpack the state vector
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  # derivatives

state0 = [0.1, 0.0, 0.0]
t = np.arange(0.0, 100.0, 0.01)

states = odeint(f, state0, t)
x = states[:, 0]
y = states[:, 1]
z = states[:, 2]
fig = plt.figure(figsize=(12,9))
ax = fig.gca(projection='3d')
ax.plot(x,y,z,'tab:pink')
fig.savefig('Atractor de Lorenze2.png',dpi=180)
plt.show()

# %%
# now plot two-dimensional cuts of the three-dimensional phase space
fig, ax = plt.subplots(1, 3, sharex=False, sharey=False, figsize=(17, 6))

# plot the x values vs the y values
ax[0].plot(x,y, color='r', alpha=0.7, linewidth=0.3)
ax[0].set_title('x-y phase plane')
#plot X Vs Z Valores
ax[1].plot(x,z , color='g', alpha=0.7, linewidth=0.3)
ax[1].set_title('x-z phase plane')

# plot  Y  vs  Z 
ax[2].plot(y,z, color='y', alpha=0.7, linewidth=0.3)
ax[2].set_title('y-z phase plane')

fig.savefig('Fase2.png', dpi=180, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as mpl
# plot the x values vs the y values
mpl.plot(t,x, color='r', alpha=0.7, linewidth=0.3)
mpl.title('x(t)2')
mpl.savefig('Xt2.png', dpi=180, bbox_inches='tight')
mpl.show()
#plot X Vs Z Valores
mpl.plot(t,y , color='g', alpha=0.7, linewidth=0.3)
mpl.title('y(t)2')
mpl.savefig('Yt2.png', dpi=180, bbox_inches='tight')
mpl.show()
# plot  Y  vs  Z 
mpl.plot(t,z, color='y', alpha=0.7, linewidth=0.3)
mpl.title('z(t)')
mpl.savefig('Zt2.png', dpi=180, bbox_inches='tight')
mpl.show()
